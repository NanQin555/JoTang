# %%
import requests
import json
import time

# %%
# 创建请求头
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.36'}
#可以自己从浏览器获取

# %%
fp = open(r'C:\Users\王南钦\Desktop\22-王南钦-10.4-138\#6-王南钦\jingdong.txt', 'w', encoding ='utf-8') 

# 循环实现翻页写入
for page in range(0, 100):
    # 通过format格式化函数实现翻页功能
    url = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=100019125569&score=0&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1'.format(page)
    print("正在爬起第" + format(page) + "页")
    response = requests.get(url, headers=headers)
    data = response.text
    # 掐头去尾，替换不需要的部分
    # 实际上也可以把url中callback=fetchJSON_comment98去掉
    # lstrip：截去左边的‘’内容；rstrip:截去右边的‘’内容
    jd = json.loads(data.lstrip('fetchJSON_comment98vv12345(').rstrip(');'))
    data_list = jd['comments'] 
    for data in data_list:
        # 提取数据
        nickname = data['nickname']
        content = data['content']
        content = content.replace('\n', '')
        creationtime = data['creationTime']
        
        print(nickname)
        print(content)
        print(creationtime)
        print()
        # 写入数据到txt文件中
        fp.write(f'{nickname}\t{content}\t{creationtime}\n')
    # 限制爬取网页速度
    time.sleep( 3 )

    
print("完成")

fp.close()
# Out:
# 正在爬起第0页
# S***u
# 包装保护：2层纸箱，内有海绵包裹很安全。外形外观：金属质感，低调的配色，个人很喜欢。运行速度：运行流畅，3种模式任意切换。画面品质：2k屏没的说，非常清晰，看起来很舒适。跑分评测：完美。其他：首发价抢到的，很香，很久没用笔记本了，发现如今的笔记本比当初好太多了。而且这款各方面都比较出色。
# 2022-03-11 21:26:33
#
# 忐***0
# 包装保护：完好外形外观：全面屏看着非常好，而且机器本身也非常漂亮画面品质：屏幕可以说太清晰了运行速度：速度老快了，画图，玩游戏都非常好，值得拥有。
# 2022-04-02 18:14:33
#
# 霎***买
# 包装保护：挺完备外形外观：大气简洁漂亮画面品质：完美高清4k跑分评测：性能综合能力强，位居前列运行速度：反应非常快游戏效果：速度快，流畅不卡，清晰度高，发热小，完全带的动基本游戏
# 2022-04-21 15:10:30
#
# c***C
# 超级开心首发买到y9000p，i5的够用了，喜欢这个大屏幕，平时看图纸用着很舒服，以后学bim，3060的也可以轻松带的动
# 2022-04-05 13:08:13
#
# y***l
# 包装保护：包装精良外形外观：商务风格，沉稳大气跑分评测：跑分给力，轻松一百五十多万分运行速度：16g镁光大内存，512G镁光固态，RTX3060显卡运行流畅游戏效果：游戏效果很棒画面品质：2k 165hz高刷新率，画质较好
# 2022-04-09 18:33:26
#
# a***3
# 包装保护：包装很结实，双包装箱保护外形外观：金属材质，太空灰很有科技感觉画面品质：清晰，高分屏玩起来眼睛不累跑分评测：鲁大师跑了130+运行速度：游戏基本都OK一点不卡顿游戏效果：非常清晰
# 2022-04-14 16:29:59
#
# a***3
# 包装保护：包装很好一点没磕碰和划痕外形外观：金属外观，商用和办公都不冲突画面品质：高分屏看起来很舒服运行速度：运行速度杠杠的，玩游戏一点都不卡顿游戏效果：任何游戏都没问题
# 2022-04-04 15:07:21
#
# F***U
# 包装保护：包装严实，安全防震。外形外观：颜值很高，外形轮廓硬朗，如同一个机械战士，充满活力。画面品质：色彩出众，亮度调节合适，显示清晰，画面细腻，看电影和刷网页眼睛一点都不累。运行速度：一代神U，速度非常快，无论是大型工作软件还是游戏都能流畅高质运行。游戏效果：游戏画面稳定，流畅度高，WIFI也很快，音响效果很好。跑分评测：不用跑，i5 12500h和3050ti的配置，高分显而易见。
# 2022-04-05 20:24:53
#
# ****8
# 终于等到y9000p有幸抢到了一台真的是太给力了新版 的logo真的帅酷了打游戏一定要首选它！颜值也是杠杠 的非常漂亮 如果喜欢打游戏一定要买它 真的是高性能 大 爱联想拯救者系列！等了好久，运气也好，抢到了最想要的y9000p正面颜值 没得说，核心卖点屏幕，看的太舒服了，高分辨+高刷， 电脑到手后甚至想把自己的显示器卖了。键盘满分不解 释。 音效也很不错， 符合游戏定位。 这个价位，基本是 各项拉满的电脑了 很合我意，快递也很好
# 2022-03-11 14:39:16
#
# 棋***粑
# 包装保护：包装外面还有箱子，保护很好一点没有损坏外形外观：金属面板还是很不错的画面品质：画面感很强，电竞屏就是比普通强运行速度：运行速度杠杠的，一点都不卡游戏效果：游戏效果不用怕开特效卡了
# 2022-04-14 16:09:35
#
# 正在爬起第1页
# 凡***-
# 包装保护：包装特别好有泡沫挡板，不用担心快递问题外形外观：外观超棒，金属感非常强画面品质：2.5k屏幕特别好，非常清晰运行速度：开机和运行速度特别快，非常流畅。游戏效果：游戏本就是不一样，打游戏非常爽，各种主流游戏都非常棒！
# 2022-03-26 18:21:11
#
# R***8
# 包装保护：包装非常完美，不管是物流箱还是内部箱，完全没有破损外形外观：ACD三面金属，A面*灰色外观，且没有灯，很低调运行速度：12代酷睿i5-12500H，运行速度非常快，不会卡顿画面品质：终于有2.5K分辨率的屏幕了，比1080p舒服太多了其他：首发买到的，机器流畅，键盘舒服，非常香！
# 2022-04-05 21:42:13
#
# J***话
# 太棒啦，第一台游戏本，万元以内，没有能打的，拯救者y9000p最完美机型，没有短板，外观游戏本的同时又兼顾商务，真的可盐可甜，配置也是杠杠的，3060加12代芯片，真的拿到机子那一刻太开心啦，屏幕看起来也很舒服，屏占比超高，可以说外观内在都做到了极致??????????
# 2022-04-17 12:06:22
#
# ****9
# 机器收到了12代英特尔酷睿i7处理器，3060显卡，2K屏，性能非常厉害，不错，做工精致，外观大气。喜欢
# 2022-03-11 12:16:24
#
# ****春
# 一直很喜欢拯救者系列，也是等了很久，不负期待，满意，做工性能都是杠杠的，要开始用他搬砖了，加油拯救者，加油打工人！！！??
# 2022-03-27 10:53:35
#
# q***7
# 对比了好久、最终等到了这款新机！第一批抢到的，很激动呀！收到货很惊喜，外形很漂亮，很有质感，键盘也很舒服，基本没有什么声音。运行速度挺快、很流畅
# 2022-03-16 09:40:06
#
# c***n
# 十分兴奋地用了几天再来评价。机器的外观很好看，金属质感很强，摸起来特别舒服，屏幕是2k屏，个人十分满意。性能释放也是中规中矩。具体硬件配是三星的内存，美光的硬盘。
# 2022-03-23 12:42:31
#
# 顺***s
# 快递速度很快，包装保护很好
# 2022-05-02 15:41:52
#
# e***1
# 到手以后用了几天，感觉很不错。包装不错，整体做工很好，屏幕显示效果很棒。背部接口上的图标会亮是的很喜欢的加分项。最好画质，无主之地115帧，远哭5平均118帧，比预期还好一些。赞。
# 2022-02-06 15:57:08
#
# M***n
# 独显直连，高性能释放，DDR5内存，非常均衡的水桶机，机器本身的发挥很好，是个好机器，16:10的屏，第一次打开那种感觉很震撼，几乎每个方面都已经接近完美了，今年备货比去年多不少。
# 2022-03-29 15:07:35
#
# 正在爬起第2页
# s***l
# 首发入手，很香1、外观：灰色金属机身，质感拉满，大气成稳，适合商务的游戏本2、性能：作为生产力使用，主要cad，revit等软件，i5+3050，足够强大，游刃有余3、显示：2.5k的分辨率，显示细腻，晚上测试没发现漏光更是大爱4、其他：支持硬盘（pcie3.0）和内存的扩容，雷电口支持显卡扩张，水桶机名符其实。
# 2022-03-17 20:38:52
#
# 牙***齿
# 运气好抢到了，隔天到货，华星光电屏幕无坏点，三星内存和显存，镁光的硬盘，机器很大气，有厚重感，很好很强大！
# 2022-04-07 12:43:24
#
# 呃***呃
# 包装保护：包装很好很严实外形外观：外观漂亮，品控严格 做工精细画面品质：高清分辨率，看电影打游戏都很舒服。运行速度：运行速度：12代英特尔处理器 ，速度很快。
# 2022-03-14 16:09:29
#
# 鹰***舞
# 画面品质：画质清晰，细腻包装保护：包装扎实，完好无损外形外观：外形美观大方运行速度：运行速度很快跑分评测：完美其他:win11最新系统使用方便快捷，预装了微软的offce软件，办公效率快捷。
# 2022-01-28 10:24:07
#
# 趙***啊
# 比较相信联想，一线大品牌，售后什么的都有保证，没有拒绝的理由啊。包装保护：无损坏外形外观：好看画面品质：很棒跑分评测：！运行速度：快游戏效果：棒
# 2022-04-03 15:03:04
#
# E***m
# y7000p我非常喜欢。做工精致。屏幕素质很好。三星的内存。京东方的屏幕。镁光的硬盘。键盘手感非常好。双扬声器。电脑反应很快。打永杰无间也不卡。首发价抢到的。价钱也非常的合适。快递的速度也非常的快。感谢京东。
# 2022-03-17 09:52:39
#
# L***n
# 完美符合我的期待，等了小半年，对比无数笔记本，选的自己都累了，最终还是上车拯救者，拯救者Y7000P性能优秀，硬盘内存都是三星，生产力符合我的预期，跑分140多万，三种显卡模式！强烈推荐！！！
# 2022-03-14 23:58:40
#
# ****8
# 包装保护：两层纸箱，内有海绵包裹，非常安全外形外观：金属质感，简约风格画面品质：2k165hz屏很舒服，非常丝滑跑分评测：很好运行速度：非常快游戏效果：非常流畅第一次首发抢到！！！爱了爱了！一天下来非常的流畅，以前的机子和这台没得比，非常推荐，准备给同学也推荐！
# 2022-03-17 17:35:46
#
# 青***c
# 包装保护：两层纸箱包着包装很好~不会磕磕碰碰外形外观：外观很漂亮 边框很窄画面品质：看着挺好的 看视频画面很清晰运行速度：反应很快没感觉有卡顿 玩游戏办公完全没问题~
# 2022-03-27 14:59:03
#
# ****o
# 选来选去最后还是拯救者，抢到当天送达，不得不说品质很好，外观颜值在线，性能不错，主要看中2k屏幕，显示细腻，用来工作打游戏都不错?
# 2022-04-03 23:32:10
#
# 正在爬起第3页
# v***o
# 谈谈两天的使用感受配置没得说 三星全家桶 缺少了p系列的&ldquo;抽奖&rdquo;环节 从下单的那一刻起就很安心做工非常的精致 用料非常的扎实 外观采用金属机身 手感类似鼠标gpro的亲肤材质 拿在手里感觉它已经不是一台笔记本电脑了 更像是一件精雕细琢的艺术品，正面颜值没得说，核心卖点屏幕，看的太舒服了，高分辨+高刷，电脑到手后甚至想把自己的显示器卖了。键盘满分不解释。音效也很不错，符合游戏定位。这个价位，基本是各项拉满的电脑了，很合我意
# 2022-03-27 12:38:03
#
# l***y
# 19年买的拯救者R系列的，这次直接升级到Y9000P2022 3060显卡。Solidworks等3D设计无压力。很赞。性价比，生产力，高性能，多个标签可以随意往拯救者身上贴。能抢到手真心不错。
# 2022-04-07 23:33:26
#
# 高***人
# 久闻联想拯救者大名，这次属于是付诸行动了，有幸抢到了首发的y9000p包装保护：包装很严实，没有任何磕碰，好评外形外观：a面d面金属，很有质感，屏幕16:10，让我一个用惯了16:9的人看着大了不少画面品质：2k高刷屏果然看着舒服，165hz也足够使用了运行速度：开机速度很快，游戏还没测，3060估计弱不了
# 2022-03-11 12:14:46
#
# 拾***_
# 包装保护：两层包装，没有破损画面品质：主要是看中2k跟高刷，看剧效果拉满游戏效果：不怎么打游戏，3050满够了，主要是i7，12代提升很大，保证5年不落伍。
# 2022-04-05 22:35:45
#
# 小***乔
# 手气真好，第一次抢就抢到了，电脑颜值很高，处理器也很棒，玩游戏再也不卡了，拯救者yyds包装保护：完美外形外观：完美画面品质：yyds跑分评测：很棒
# 2022-03-11 18:56:28
#
# ****5
# 抢到了首发，10号的尾款，11号就收到了，给力。机器质感非常好，3060够用了，2.5k屏也很不错，固态和内存也是三星的非常不错，后期再加装一条980就完美了。2011买过一台笔记本，现在的笔记本进步太大了。
# 2022-03-11 21:53:43
#
# z***1
# 性价比还是比较高的，产品也好用！
# 2022-04-15 11:25:50
#
# x***g
# 孩子上学需要一个笔记本，在网上看了好多，联想做工质量普遍挺好，孩子同学用的基本全是联想，刚好看到3月10日0.00有首发运气好抢了一台，收到货挺满意，外观性能比上代提升许多，还是12代u，试用了几天性价比很高，非常满意。
# 2022-03-13 12:42:38
#
# -***-
# 个人感觉挺好的，本来想买21款的，22款发售了那肯定买新不买旧。2k屏幕清晰度特别好，玩玩联盟等游戏配置也足够，三星内存，镁光硬盘，跑分135w，供各位机友参考，自己后期又加了块三星p@a1硬盘，我永远相信京东自营！赞赞赞！！！
# 2022-04-22 11:26:11
#
# 王***错
# 终于抢到了，实际要比广告上轻薄，质感很好，顶底是金属的，两个档位的键盘背光，运行速度很快，开机七八秒，没有安装测试的软件因为怕卡怕流氓软件，软件用联想自带和系统自带就可以，目前玩了十多天主要是用一些设计软件cad酷家乐之类的，因为cad是07的老版的很流畅，没有21版本所以测试不出到底有多流畅，酷家乐没问题，3d我没有安装，因为渲染还是老实用台式，还买了京东的延保，买这个主要还是工作用，作为室内设计师用这个确实比果子好，更加兼容设计类软件，如果做视频平面设计之类剪辑后期可以考虑果子，我几乎就是办公所以没有买顶配，如果打游戏可以考虑顶配，总体确实不错！
# 2022-04-02 23:45:26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#      27         fp.write(f'{nickname}%%!{content}%%!{creationtime}\n')
#      28     # 限制爬取网页速度
# ---> 29     time.sleep( 3 )
#      32 print("完成")
#      34 fp.close()
#
# KeyboardInterrupt:
